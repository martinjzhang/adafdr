# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Test airway

# %%
## loading airway data
p,x = load_airway(verbose=True)

## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,verbose=True)
#print('FDP: %s \n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,verbose=True)
# Out:
# ## airway data ##
# # hypothesis: 33469
# p=0.000153542287814, x=6.56329425437
# p=0.0655868795554, x=6.25440153322
# p=0.793765241592, x=5.4687478236
# p=0.735407241539, x=4.05928083764
# p=0.578223628721, x=-1.14539457803
#
#
# ## bh testing summary ##
# # n_rej = 4079
# # t_rej = 0.012180
#
#
# ## sbh summary ##
# # n_rej = 4079
# # t_rej = 0.012180
# # pi_0 estimate = 1.000

# %%
n_rej,t,_=PrimFDR(p,x,5,alpha=0.1,h=None,n_itr=100,verbose=True)
# Out:
# PrimFDR check1
# ## PrimFDR_init starts
# # Learning null distribution
# Slope: w=0.705256153522679, a=-1.2108251953125002
# Bump 0: w=0.07778409061955342, mu=[0.37578967], sigma=[0.07018061]
# Bump 1: w=0.10896885735747473, mu=[0.20330651], sigma=[0.05573656]
# Bump 2: w=0.03010524780535944, mu=[0.52604821], sigma=[0.05846854]
# Bump 3: w=0.07526803338473838, mu=[0.0828516], sigma=[0.03884809]
# Bump 4: w=0.0026176173101949847, mu=[0.81567498], sigma=[0.05119699]
# # Learning alternative distribution
# Slope: w=0.0041669980936612505, a=3.4764501953125
# Bump 0: w=0.24205898775732135, mu=[0.80338708], sigma=[0.04473861]
# Bump 1: w=0.26685454743968096, mu=[0.90121532], sigma=[0.03437106]
# Bump 2: w=0.0742957564661649, mu=[0.6074548], sigma=[0.06886084]
# Bump 3: w=0.24463158392261625, mu=[0.96971651], sigma=[0.01960171]
# Bump 4: w=0.16799212632055527, mu=[0.69041252], sigma=[0.04968515]
# # Test result with PrimFDR_init
# # Num of discovery: 6057
# ## PrimFDR_init finishes
#
# PrimFDR check2
# ## optimization paramter:
# # n_itr=100, n_samp=33469, lambda0=581, lambda1=100
#
# ## optimization initialization:
# # Slope: a=[3.4764502], b=[-10.220285]
# # Bump 0: w=-1.7712864, mu=[0.8033871], sigma=[0.00400309]
# # Bump 1: w=-1.4101423, mu=[0.9012153], sigma=[0.00236274]
# # Bump 2: w=-3.3836646, mu=[0.6074548], sigma=[0.00948363]
# # Bump 3: w=-0.93549466, mu=[0.9697165], sigma=[0.00076845]
# # Bump 4: w=-2.24142, mu=[0.6904125], sigma=[0.00493723]
#
#
# PrimFDR check3
# PrimFDR check
# ## iteration 0
# n_rej:  7299
# n_rej sig:  7300.743
# FD esti mirror: 1257
# FD esti mirror sig: 1270.9467
# loss1:  [-0.2181345]
# loss2:  [1.6160396]
# Estimated FDP: [0.17408456]
# FDP: 0.0
# Slope: a=[3.4714503], b=[-10.225286]
# Bump 0: w=-1.7762864, mu=[0.8083871], sigma=[0.00400309]
# Bump 1: w=-1.4151423, mu=[0.8962153], sigma=[0.00236274]
# Bump 2: w=-3.3886645, mu=[0.6124548], sigma=[0.00948363]
# Bump 3: w=-0.94049466, mu=[0.9647165], sigma=[0.00076845]
# Bump 4: w=-2.2464201, mu=[0.6854125], sigma=[0.00493723]
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# ## iteration 20
# n_rej:  6644
# n_rej sig:  6649.6133
# FD esti mirror: 888
# FD esti mirror sig: 910.6367
# loss1:  [-0.19867979]
# loss2:  [0.73403865]
# Estimated FDP: [0.13694581]
# FDP: 0.0
# Slope: a=[3.3774114], b=[-10.320045]
# Bump 0: w=-1.8728863, mu=[0.8274171], sigma=[0.00400309]
# Bump 1: w=-1.4977269, mu=[0.900634], sigma=[0.00236274]
# Bump 2: w=-3.480307, mu=[0.6934452], sigma=[0.00948363]
# Bump 3: w=-1.0187142, mu=[1.0304356], sigma=[0.00076845]
# Bump 4: w=-2.3424082, mu=[0.6956356], sigma=[0.00493723]
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# ## iteration 40
# n_rej:  6318
# n_rej sig:  6306.123
# FD esti mirror: 781
# FD esti mirror sig: 803.00024
# loss1:  [-0.18841684]
# loss2:  [0.5150676]
# Estimated FDP: [0.1273366]
# FDP: 0.0
# Slope: a=[3.2928035], b=[-10.405161]
# Bump 0: w=-1.9643303, mu=[0.8420262], sigma=[0.00400309]
# Bump 1: w=-1.5891321, mu=[0.9016677], sigma=[0.00236274]
# Bump 2: w=-3.5586164, mu=[0.7200252], sigma=[0.00948363]
# Bump 3: w=-1.0388614, mu=[1.0612688], sigma=[0.00076845]
# Bump 4: w=-2.4336534, mu=[0.724757], sigma=[0.00493723]
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# ## iteration 60
# n_rej:  6162
# n_rej sig:  6145.5723
# FD esti mirror: 702
# FD esti mirror sig: 723.4121
# loss1:  [-0.18361984]
# loss2:  [0.32524055]
# Estimated FDP: [0.11771271]
# FDP: 0.0
# Slope: a=[3.2187924], b=[-10.480922]
# Bump 0: w=-2.0491433, mu=[0.8511442], sigma=[0.00400309]
# Bump 1: w=-1.6887219, mu=[0.9034209], sigma=[0.00236274]
# Bump 2: w=-3.6445277, mu=[0.70741695], sigma=[0.00948363]
# Bump 3: w=-1.0418609, mu=[1.0652381], sigma=[0.00076845]
# Bump 4: w=-2.537863, mu=[0.7386558], sigma=[0.00493723]
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# ## iteration 80
# n_rej:  6017
# n_rej sig:  5998.611
# FD esti mirror: 630
# FD esti mirror sig: 654.274
# loss1:  [-0.17922886]
# loss2:  [0.16257706]
# Estimated FDP: [0.10907092]
# FDP: 0.0
# Slope: a=[3.1514828], b=[-10.551654]
# Bump 0: w=-2.1259997, mu=[0.86867094], sigma=[0.00400309]
# Bump 1: w=-1.7777365, mu=[0.90030676], sigma=[0.00236274]
# Bump 2: w=-3.730726, mu=[0.7055164], sigma=[0.00948363]
# Bump 3: w=-1.0421356, mu=[1.0642959], sigma=[0.00076845]
# Bump 4: w=-2.6349163, mu=[0.73114187], sigma=[0.00493723]
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check
# PrimFDR check4
# # Num of discovery: 5913
#
#
# PrimFDR check5

# %%
_=PrimFDR_cv(p,x,5,alpha=0.1,n_itr=100,h=None,verbose=True,core='s_core')

# %%
_=PrimFDR_cv(p,x,5,alpha=0.1,n_itr=100,h=None,verbose=True,core='m_core')
# Out:
# #time start: 0.0s
# #time input: 0.0009s
# pfdr_test start
# PrimFDR check1
# PrimFDR start
# pfdr_test start
# PrimFDR start
# PrimFDR check1
# pfdr_test start
# PrimFDR start
# PrimFDR check1
# PrimFDR check2
# PrimFDR check3
# PrimFDR check
# PrimFDR check2
# PrimFDR check2
# PrimFDR check3
# PrimFDR check3
# PrimFDR check
# PrimFDR check
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2c515822b46a> in <module>()
# ----> 1 _=PrimFDR_cv(p,x,5,alpha=0.1,n_itr=100,h=None,verbose=True,core='m_core')
#
# ~/NeuralFDR2/NeuralFDR2/prim_fdr.py in PrimFDR_cv(p, x, K, alpha, n_itr, qt_norm, reorder, h, core, verbose)
#     213     if core == 'm_core':
#     214     ## multi-processing
# --> 215         pool = Pool(3)
#     216         res  = pool.map(pfdr_test, Y_input)
#     217         if verbose: print('#time mp: %0.4fs'%(time.time()-start_time))
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
