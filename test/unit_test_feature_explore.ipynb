# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from nfdr2.util import *
import nfdr2.prim_fdr as pf
import nfdr2.data_loader as dl

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### GTEx: feature exploration

# %%
## loading GTEx 
p,x,n_full,cate_name = dl.load_GTEx_full(verbose=True)

## testing the BH method
n_rej,t_rej=dl.bh(p,alpha=0.1,n_full=n_full,verbose=True)

## testing the Storey BH method
n_rej,t_rej,pi0_hat=dl.storey_bh(p,alpha=0.1,n_full=n_full,lamb=0.995,verbose=True)
# Out:
# ## Load GTEx full data ##
# # all hypothesis: 10623893
# # filtered hypothesis: 169301
# # p=0.00226011, x=[13.7358  0.0896  0.112  16.    ]
# # p=0.00254028, x=[13.7461  0.0896  0.     16.    ]
# # p=0.000610689, x=[13.7478  0.0896  0.     16.    ]
# # p=0.00071358, x=[13.7479  0.0896  0.012  16.    ]
# # p=0.000228687, x=[13.7482  0.0896  0.209  13.    ]
#
#
# ## bh testing summary ##
# # n_rej = 29348
# # t_rej = 0.000276
#
#
# ## pi0_hat=0.975
# ## sbh summary ##
# # n_rej = 29689
# # t_rej = 0.000286
# # pi_0 estimate = 0.975

# %% [markdown]
# ## test feature_preprocess

# %%
x_,meta_info = feature_preprocess(x,p,return_metainfo=True,verbose=True)

# %%
pf.feature_explore(p,x,alpha=0.1,n_full=n_full,vis_dim=None,cate_name=cate_name,\
                       output_folder=None,h=None,log_transform=None)
# Out:
# [22 20  0  3  7  9 14 19  1 21 10 11  2  4  8 18 15 13 24 16 12 23  6 17
#   5]
# [19. 19. 19. 19. 17. 19. 19. 22. 17. 17. 17. 17.  4.  4.  4.  4.  4.  4.
#  15. 15.]

# %% [markdown]
# ### airway: feature exploration

# %%
p,x = load_airway(verbose=False)
feature_explore(p,x,alpha=0.1,qt_norm=False)

# %%
p,x = load_airway(verbose=False)
feature_explore(p,x,alpha=0.1,qt_norm=True)

# %%
plt.figure()
plt.scatter(x,p,alpha=0.01)
plt.show()

# %% [markdown]
# ### mixture_fit_new
