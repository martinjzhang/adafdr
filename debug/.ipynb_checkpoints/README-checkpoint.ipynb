# %%
import adafdr.method as md
import adafdr.data_loader as dl
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
p,x = dl.data_airway()

# %%
adafdr.method.adafdr_explore(p, x)

# %%
n_rej,t_rej,theta = md.adafdr_test(p, x, fast_mode=False, verbose=True)
# Out:
# ## method_init_2
# # Num of discovery: 1190
#
# ## method_init_1
# # Num of discovery: 986
#
# ## method_single_fold_2
# # Num of discovery: 1236
#
# ## method_single_fold_1
# # Num of discovery: 1058
#
# # total rejection: 2144 [1109, 1035]
# #time total: 51.0836s

# %%
n_rej
# Out:
# [3007, 3043]
